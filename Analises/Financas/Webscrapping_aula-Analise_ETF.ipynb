# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import astropy.units as u
import math
import scipy.stats as stats
from tqdm import tqdm 
import time
import multiprocessing as mp
from scipy.stats import norm
from scipy.stats import poisson
from scipy.optimize import curve_fit
#import latexify
import random
import scipy.special as sp
from scipy import signal
from scipy.fft import fft, fftfreq, fftshift
from scipy.signal import butter, freqz, filtfilt
import datetime
import yfinance as yf
import mplcyberpunk
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders
import time

# %% [markdown]
# ## Análise ETF - Webscrapping
# É possível analisar receita de empresas de aviação, seguro, roupas...
#
# Vamos construir um código que vá no site etf.com e busque dados de todos os etfs do mercado mundial. Rentabilidaddes, patrimônio, gestora, taxa...
#
# #### Será necessário:
# - definir navegador a ser utilizado
# - entender requisições na internet
# - conhecer e mapear o processo de coleta de dados no site ETF.com
# - encontrar os elementos necessarios dentro do HTML
# - construir tabela final

# %%
from selenium import webdriver
from selenium.webdriver.firefox.service import Service as FirefoxService
from webdriver_manager.firefox import GeckoDriverManager

# %% [markdown]
# - Como funcionam requisições na internet

# %% [markdown]
# HTTP é um protocolo (protocol) que permite a obtenção de recursos, como documentos HTML. É a base de qualquer troca de dados na Web e um protocolo cliente-servidor, o que significa que as requisições são iniciadas pelo destinatário, geralmente um navegador da Web. Um documento completo é reconstruído a partir dos diferentes sub-documentos obtidos, como por exemplo texto, descrição do layout, imagens, vídeos, scripts e muito mais.
#
# Clientes e servidores se comunicam trocando mensagens individuais (ao contrário de um fluxo de dados). As mensagens enviadas pelo cliente, geralmente um navegador da Web, são chamadas de solicitações (requests), ou também **requisições**, e as mensagens enviadas pelo servidor como resposta são chamadas de respostas (responses).
#
# O HTTP é um protocolo cliente-servidor: as requisições são enviados por uma entidade, o agente-usuário (ou um proxy em nome dele). A maior parte do tempo, o agente-usuário é um navegador da Web, mas pode ser qualquer coisa, como por exemplo um robô que varre a Web para preencher e manter um índice de mecanismo de pesquisa e coletar informações.
#
# Cada requisição individual é enviada para um servidor, que irá lidar com isso e fornecer um resultado, chamado de resposta. Entre a solicitação e a resposta existem várias entidades, designadas coletivamente como proxies, que executam operações diferentes e atuam como gateways (intermediários) ou caches, por exemplo.
#
# Na realidade, existem muitos outros computadores entre o navegador e o servidor que está tratando a requisição: existem roteadores, modems e muito mais. Graças ao modelo de camadas da Web, essas funcionalidades estão escondidas nas camadas de rede e transporte, respectivamente. O HTTP está no topo da camada de aplicação.
#
# *fonte: https://developer.mozilla.org/pt-BR/docs/Web/HTTP/Overview *

# %% [markdown]
# Ao acessar qualquer site, o computador pede um get() e o servidor deve autorizar. Quando estamos fazendo um login em algum site, estamos fazendo um post(), e esperamos uma resposta (no caso, sobre a validade da senha).

# %%
driver = webdriver.Firefox( service=FirefoxService(GeckoDriverManager().install())
)#nosso bot que irá abrir o navegador e procurar os sites
# Out:
# [WDM] - Downloading: 16.9kB [00:00, 2.96MB/s]

# %%
#Ex1
url = "https:www.google.com"
driver.get(url)

# %%
url = "https://www.etf.com/etfanalytics/etf-finder"
driver.get(url)

# %%
'''
plano: o bot abrir a pagina, mudar a visualizar 100, copiar toda a tabela, 
guardar, e passar a página, 
copiar a tabela...
(OBS: copy full xpath)
'''
time.sleep(7) #Python é mais rapido que o carregamento da tabela
# achar botao viz100
botao_100 = driver.find_element("xpath", '''/html/body/div[5]/section/div/div[3]/section/div/div/div/
div/div[2]/section[2]/div[2]/section[2]/div[1]/div/div[4]/button/label/span''')
#clicar
driver.execute_script("arguments[0].click()", botao_100)

#encontrar o numero total de paginas para fazer loop
numero_paginas = driver.find_element("xpath",'''
/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/section[2]/div[2]/div/label[2]
''')
print(numero_paginas.text)
# Out:
# of 32

# %%
#pegando elemento numerico
numero_paginas = int(numero_paginas.text.replace("of",""))
numero_paginas
# Out:
# 32

# %%
#criando loop para ler a tabela de dados (ler rentabilidade)
html_tabela = driver.find_element("xpath", '''
/html/body/div[5]/section/div/div[3]/section/div/div/div/
div/div[2]/section[2]/div[2]/div/table
''')

html_tabela = html_tabela.get_attribute("outerHTML")
#Agora leremos HTML com pandas :D
tabela = pd.read_html(html_tabela)[0] #recortar primeira p ignorar outros elementos html
tabela
# Out:
#    Ticker                                           Name  \
# 0     SPY                         SPDR S&P 500 ETF Trust
# 1     IVV                       iShares Core S&P 500 ETF
# 2     VTI                Vanguard Total Stock Market ETF
# 3     VOO                           Vanguard S&P 500 ETF
# 4     QQQ                              Invesco QQQ Trust
# ..    ...                                            ...
# 95    VXF                   Vanguard Extended Market ETF
# 96    XLI             Industrial Select Sector SPDR Fund
# 97    PFF    iShares Preferred and Income Securities ETF
# 98   VGIT  Vanguard Intermediate-Term Treasury Index ETF
# 99   SCHP                           Schwab U.S. TIPS ETF
#
#                                               Segment  \
# 0                            Equity: U.S. - Large Cap
# 1                            Equity: U.S. - Large Cap
# 2                         Equity: U.S. - Total Market
# 3                            Equity: U.S. - Large Cap
# 4                            Equity: U.S. - Large Cap
# ..                                                ...
# 95                     Equity: U.S. - Extended Market
# 96                           Equity: U.S. Industrials
# 97          Fixed Income: U.S. - Corporate, Preferred
# 98  Fixed Income: U.S. - Government, Treasury Inve...
# 99  Fixed Income: U.S. - Government, Inflation-lin...
#
#                           Issuer Expense Ratio       AUM
# 0   State Street Global Advisors         0.09%  $379.11B
# 1                      Blackrock         0.03%  $310.04B
# 2                       Vanguard         0.03%  $284.32B
# 3                       Vanguard         0.03%  $282.26B
# 4                        Invesco         0.20%  $161.85B
# ..                           ...           ...       ...
# 95                      Vanguard         0.06%   $14.69B
# 96  State Street Global Advisors         0.10%   $14.15B
# 97                     Blackrock         0.45%   $13.97B
# 98                      Vanguard         0.04%   $13.95B
# 99                Charles Schwab         0.04%   $13.82B
#
# [100 rows x 6 columns]

# %%
#Guardar as informações da tabela da primeira pagina e avançar de pagina
tabelas = []

for i in range(0,numero_paginas):
    html_tabela = driver.find_element("xpath", '''
/html/body/div[5]/section/div/div[3]/section/div/div/div/
div/div[2]/section[2]/div[2]/div/table
''')

    html_tabela = html_tabela.get_attribute("outerHTML")
#Agora leremos HTML com pandas :D
    tabela = pd.read_html(html_tabela)[0] #recortar primeira p ignorar outros elementos html
    tabelas.append(tabela)
#Encontrar o botao de avancar pagina e clicar
    avancar = driver.find_element("xpath", "/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/section[2]/div[2]/div/span[2]")
    driver.execute_script("arguments[0].click();", avancar)

# %%
#Tranformar a lista de dataframes num grande dataframe

# %%
## Tutorial de concatenação de dataframes:

df1 = pd.DataFrame(
    {
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    },
)


df2 = pd.DataFrame(
    {
        "A": ["A4", "A5", "A6", "A7"],
        "B": ["B4", "B5", "B6", "B7"],
        "C": ["C4", "C5", "C6", "C7"],
        "D": ["D4", "D5", "D6", "D7"],
    },
)

pd.concat([df1, df2], ignore_index = True)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
pd.concat([df1, df2], ignore_index = True)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
tabelas = pd.concat(tabelas)

# %%
tabelas
# Out:
#    Ticker                                               Name  \
# 0     SPY                             SPDR S&P 500 ETF Trust
# 1     IVV                           iShares Core S&P 500 ETF
# 2     VTI                    Vanguard Total Stock Market ETF
# 3     VOO                               Vanguard S&P 500 ETF
# 4     QQQ                                  Invesco QQQ Trust
# ..    ...                                                ...
# 8    CVSB           Calvert Ultra-Short Investment Grade ETF
# 9    CVLC    Calvert US Large-Cap Core Responsible Index ETF
# 10   CVMC      Calvert US Mid-Cap Core Responsible Index ETF
# 11   CVIE        Calvert International Responsible Index ETF
# 12   CDEI  Calvert US Large-Cap Diversity, Equity and Inc...
#
#                                               Segment  \
# 0                            Equity: U.S. - Large Cap
# 1                            Equity: U.S. - Large Cap
# 2                         Equity: U.S. - Total Market
# 3                            Equity: U.S. - Large Cap
# 4                            Equity: U.S. - Large Cap
# ..                                                ...
# 8   Fixed Income: Global - Broad Market, Broad-bas...
# 9                            Equity: U.S. - Large Cap
# 10                             Equity: U.S. - Mid Cap
# 11      Equity: Developed Markets Ex-U.S. - Large Cap
# 12                           Equity: U.S. - Large Cap
#
#                           Issuer Expense Ratio       AUM
# 0   State Street Global Advisors         0.09%  $379.11B
# 1                      Blackrock         0.03%  $310.04B
# 2                       Vanguard         0.03%  $284.32B
# 3                       Vanguard         0.03%  $282.26B
# 4                        Invesco         0.20%  $161.85B
# ..                           ...           ...       ...
# 8                 Morgan Stanley         0.24%        --
# 9                 Morgan Stanley            --        --
# 10                Morgan Stanley         0.15%        --
# 11                Morgan Stanley            --        --
# 12                Morgan Stanley            --        --
#
# [3113 rows x 6 columns]

# %%
### Lendo a tabela de performance
#botao performance
botao_aba = driver.find_element("xpath",'''
/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/
section[2]/div[2]/ul/li[2]/span
''')

driver.execute_script("arguments[0].click()", botao_aba)

# %%
#verificar se o numero total de paginas continua o mesmo
numero_paginas = driver.find_element("xpath",'''
/html/body/div[5]/section/div/div[3]/section/div/div/div/div/
div[2]/section[2]/div[2]/section[2]/div[2]/div/label[2]
''')
numero_paginas = int(numero_paginas.text.replace("of",""))

#Voltar pra pagina 1 e fazer o mesmo loop anteriormente
for i in range(numero_paginas):   
    voltar = driver.find_element("xpath",'''
    /html/body/div[5]/section/div/div[3]/section/div/div/
    div/div/div[2]/section[2]/div[2]/section[2]/div[2]/div/span[1]
    ''')
    driver.execute_script("arguments[0].click()", voltar)

tabelas_p = []

for i in range(0,numero_paginas):
    html_tabela = driver.find_element("xpath", '''
/html/body/div[5]/section/div/div[3]/section/div/div/div/div/
div[2]/section[2]/div[2]/div/table
''')

    html_tabela = html_tabela.get_attribute("outerHTML")
#Agora leremos HTML com pandas :D
    tabela = pd.read_html(html_tabela)[0] #recortar primeira p ignorar outros elementos html
    tabelas_p.append(tabela)
#Encontrar o botao de avancar pagina e clicar
    avancar = driver.find_element("xpath", "/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/section[2]/div[2]/div/span[2]")
    driver.execute_script("arguments[0].click();", avancar)

# %%
tabelas_p = pd.concat(tabelas_p)

tabelas_p
# Out:
#    Ticker                                               Name 1 Month 3 Month  \
# 0     SPY                             SPDR S&P 500 ETF Trust   4.96%   9.32%
# 1     IVV                           iShares Core S&P 500 ETF   5.01%   9.33%
# 2     VTI                    Vanguard Total Stock Market ETF   5.42%   9.66%
# 3     VOO                               Vanguard S&P 500 ETF   4.99%   9.31%
# 4     QQQ                                  Invesco QQQ Trust  11.51%  14.85%
# ..    ...                                                ...     ...     ...
# 8    CVSB           Calvert Ultra-Short Investment Grade ETF      --      --
# 9    CVLC    Calvert US Large-Cap Core Responsible Index ETF      --      --
# 10   CVMC      Calvert US Mid-Cap Core Responsible Index ETF      --      --
# 11   CVIE        Calvert International Responsible Index ETF      --      --
# 12   CDEI  Calvert US Large-Cap Diversity, Equity and Inc...      --      --
#
#        YTD   1 Year 3 Years 5 Years 10 Years As Of Date
# 0    6.45%   -9.58%   8.73%  11.15%   12.44%   02/09/23
# 1    6.47%   -9.55%   8.74%  11.17%   12.50%   02/09/23
# 2    7.03%  -10.06%   8.29%  10.66%   12.08%   02/09/23
# 3    6.48%   -9.57%   8.71%  11.17%   12.50%   02/09/23
# 4   13.29%  -17.13%  10.27%  14.91%   17.15%   02/09/23
# ..     ...      ...     ...     ...      ...        ...
# 8       --       --      --      --       --   02/09/23
# 9       --       --      --      --       --   02/09/23
# 10      --       --      --      --       --   02/09/23
# 11      --       --      --      --       --   02/09/23
# 12      --       --      --      --       --   02/09/23
#
# [3113 rows x 10 columns]

# %%
# Exercicio: Buscar uma terceira tabela com todas as paginas da aba Fundamentals

#botao Fundamentals
botao_aba = driver.find_element("xpath",'''
/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/ul/li[5]/span
''')

driver.execute_script("arguments[0].click()", botao_aba)

#verificar se o numero total de paginas continua o mesmo
numero_paginas = driver.find_element("xpath",'''
/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/section[2]/div[2]/div/label[2]
''')
numero_paginas = int(numero_paginas.text.replace("of",""))

#Voltar pra pagina 1 e fazer o mesmo loop anteriormente
for i in range(numero_paginas):   
    voltar = driver.find_element("xpath",'''
    /html/body/div[5]/section/div/div[3]/section/div/div/
    div/div/div[2]/section[2]/div[2]/section[2]/div[2]/div/span[1]
    ''')
    driver.execute_script("arguments[0].click()", voltar)

tabelas_f = []

for i in range(0,numero_paginas):
    html_tabela = driver.find_element("xpath", '''
/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/div/table
''')

    html_tabela = html_tabela.get_attribute("outerHTML")
#Agora leremos HTML com pandas :D
    tabela = pd.read_html(html_tabela)[0] #recortar primeira p ignorar outros elementos html
    tabelas_f.append(tabela)
#Encontrar o botao de avancar pagina e clicar
    avancar = driver.find_element("xpath", "/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/section[2]/div[2]/div/span[2]")
    driver.execute_script("arguments[0].click();", avancar)

tabelas_f = pd.concat(tabelas_f)

# %%
## Juntando tabela de cadastros com a de rentabilidade (tabelas e tabelas_p):

#Colocar o ticker como indeces, inves dos numeros de linhas

tabelas = tabelas.set_index("Ticker")
tabelas_p = tabelas_p.set_index("Ticker")
#tabelas_f = tabelas_f.set_index("Ticker") dando erro, ver dps

# %%
#Adicionar as informações da rentabilidade em cada ano à tabela inicial
tabelas_p[['1 Year', '3 Years', '5 Years','10 Years']]
# Out:
#          1 Year 3 Years 5 Years 10 Years
# Ticker
# SPY      -9.58%   8.73%  11.15%   12.44%
# IVV      -9.55%   8.74%  11.17%   12.50%
# VTI     -10.06%   8.29%  10.66%   12.08%
# VOO      -9.57%   8.71%  11.17%   12.50%
# QQQ     -17.13%  10.27%  14.91%   17.15%
# ...         ...     ...     ...      ...
# CVSB         --      --      --       --
# CVLC         --      --      --       --
# CVMC         --      --      --       --
# CVIE         --      --      --       --
# CDEI         --      --      --       --
#
# [3113 rows x 4 columns]

# %%
tabelas = tabelas.join(tabelas_p[['1 Year', '3 Years', '5 Years','10 Years']])
tabelas
# Out:
#                                                      Name  \
# Ticker
# SPY                                SPDR S&P 500 ETF Trust
# IVV                              iShares Core S&P 500 ETF
# VTI                       Vanguard Total Stock Market ETF
# VOO                                  Vanguard S&P 500 ETF
# QQQ                                     Invesco QQQ Trust
# ...                                                   ...
# CVSB             Calvert Ultra-Short Investment Grade ETF
# CVLC      Calvert US Large-Cap Core Responsible Index ETF
# CVMC        Calvert US Mid-Cap Core Responsible Index ETF
# CVIE          Calvert International Responsible Index ETF
# CDEI    Calvert US Large-Cap Diversity, Equity and Inc...
#
#                                                   Segment  \
# Ticker
# SPY                              Equity: U.S. - Large Cap
# IVV                              Equity: U.S. - Large Cap
# VTI                           Equity: U.S. - Total Market
# VOO                              Equity: U.S. - Large Cap
# QQQ                              Equity: U.S. - Large Cap
# ...                                                   ...
# CVSB    Fixed Income: Global - Broad Market, Broad-bas...
# CVLC                             Equity: U.S. - Large Cap
# CVMC                               Equity: U.S. - Mid Cap
# CVIE        Equity: Developed Markets Ex-U.S. - Large Cap
# CDEI                             Equity: U.S. - Large Cap
#
#                               Issuer Expense Ratio       AUM   1 Year 3 Years  \
# Ticker
# SPY     State Street Global Advisors         0.09%  $379.11B   -9.58%   8.73%
# IVV                        Blackrock         0.03%  $310.04B   -9.55%   8.74%
# VTI                         Vanguard         0.03%  $284.32B  -10.06%   8.29%
# VOO                         Vanguard         0.03%  $282.26B   -9.57%   8.71%
# QQQ                          Invesco         0.20%  $161.85B  -17.13%  10.27%
# ...                              ...           ...       ...      ...     ...
# CVSB                  Morgan Stanley         0.24%        --       --      --
# CVLC                  Morgan Stanley            --        --       --      --
# CVMC                  Morgan Stanley         0.15%        --       --      --
# CVIE                  Morgan Stanley            --        --       --      --
# CDEI                  Morgan Stanley            --        --       --      --
#
#        5 Years 10 Years
# Ticker
# SPY     11.15%   12.44%
# IVV     11.17%   12.50%
# VTI     10.66%   12.08%
# VOO     11.17%   12.50%
# QQQ     14.91%   17.15%
# ...        ...      ...
# CVSB        --       --
# CVLC        --       --
# CVMC        --       --
# CVIE        --       --
# CDEI        --       --
#
# [3113 rows x 9 columns]

# %% [markdown]
# - Isso é possível pois possuem os mesmos indeces! Nesse caso, o ticker de cada ETF

# %%
# Fechando o navegador
driver.quit()

# %% [markdown]
# ### Analise das ETFs

# %% [markdown]
#  - Escolher os períodos de rentabilidade analisados
#  - Retirar os dados faltantes
#  - Transformar as rentabilidades em numeros decimais
#  - Filtrar os ETFs alavancados
#  - Rankear a rentabilidade

# %%
tabelas = tabelas.replace("--",pd.NA)
tabelas = tabelas.dropna()

# %%
# convertendo em decimal
tabelas['1 Year'] = (tabelas['1 Year'].str.rstrip('%').astype(float)/100)

tabelas['3 Years'] = (tabelas['3 Years'].str.rstrip('%').astype(float)/100)

tabelas['5 Years'] = (tabelas['5 Years'].str.rstrip('%').astype(float)/100)

tabelas['10 Years'] = (tabelas['10 Years'].str.rstrip('%').astype(float)/100)

# %%
tabelas
# Out:
#                                                   Name  \
# Ticker
# SPY                             SPDR S&P 500 ETF Trust
# IVV                           iShares Core S&P 500 ETF
# VTI                    Vanguard Total Stock Market ETF
# VOO                               Vanguard S&P 500 ETF
# QQQ                                  Invesco QQQ Trust
# ...                                                ...
# SZK                ProShares UltraShort Consumer Goods
# LD      iPath Bloomberg Lead Subindex Total Return ETN
# ERUS                           iShares MSCI Russia ETF
# LTL                 ProShares Ultra Telecommunications
# RSXJ                       VanEck Russia Small-Cap ETF
#
#                                       Segment                        Issuer  \
# Ticker
# SPY                  Equity: U.S. - Large Cap  State Street Global Advisors
# IVV                  Equity: U.S. - Large Cap                     Blackrock
# VTI               Equity: U.S. - Total Market                      Vanguard
# VOO                  Equity: U.S. - Large Cap                      Vanguard
# QQQ                  Equity: U.S. - Large Cap                       Invesco
# ...                                       ...                           ...
# SZK     Inverse Equity: U.S. Consumer Staples                     ProShares
# LD        Commodities: Industrial Metals Lead         Barclays Capital Inc.
# ERUS            Equity: Russia - Total Market                     Blackrock
# LTL           Leveraged Equity: U.S. Telecoms                     ProShares
# RSXJ               Equity: Russia - Small Cap                        VanEck
#
#        Expense Ratio       AUM  1 Year  3 Years  5 Years  10 Years
# Ticker
# SPY            0.09%  $379.11B -0.0958   0.0873   0.1115    0.1244
# IVV            0.03%  $310.04B -0.0955   0.0874   0.1117    0.1250
# VTI            0.03%  $284.32B -0.1006   0.0829   0.1066    0.1208
# VOO            0.03%  $282.26B -0.0957   0.0871   0.1117    0.1250
# QQQ            0.20%  $161.85B -0.1713   0.1027   0.1491    0.1715
# ...              ...       ...     ...      ...      ...       ...
# SZK            0.95%    $1.30M  0.1685  -0.2919  -0.2471   -0.2359
# LD             0.70%    $1.24M -0.0370   0.0645  -0.0528   -0.0239
# ERUS           0.08%  $961.13K -0.8055  -0.4002  -0.2193   -0.1300
# LTL            0.95%  $668.72K -0.3259  -0.0636  -0.0109    0.0205
# RSXJ           0.67%  $387.25K -0.6430  -0.3123  -0.1951   -0.1081
#
# [892 rows x 9 columns]

# %% [markdown]
# '''
# Era possível também ter limpado o tabelas_p antes com dropna e dps dado .join com a tabelas
# usando join(how='inner') que aceita apenas a interseção das duas tabelas com mesmos indices.
# '''

# %%
## ETFs promissores

#Filtro começa retirando ETFs Leverage que são mais arriscados
tabelas = tabelas[~tabelas['Segment'].str.contains("Leveraged")] 
#Recortando tudo que não tiver a palavra Leveraged no nome da coluna Segments e salvando na variavel (basicamente retirando tudo que tenha a palavra)

#adicionando colunas de ranking para cada ETF com base em sua rentabilidade por x anos
tabelas['Rank_1_ano'] = tabelas['1 Year'].rank(ascending = False)

tabelas['Rank_3_anos'] = tabelas['3 Years'].rank(ascending = False)

tabelas['Rank_5_anos'] = tabelas['5 Years'].rank(ascending = False)

tabelas['Rank_10_anos'] = tabelas['10 Years'].rank(ascending = False)
# Out:
# <ipython-input-27-62bd20c96505>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tabelas['Rank_1_ano'] = tabelas['1 Year'].rank(ascending = False)
# <ipython-input-27-62bd20c96505>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tabelas['Rank_3_anos'] = tabelas['3 Years'].rank(ascending = False)
# <ipython-input-27-62bd20c96505>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tabelas['Rank_5_anos'] = tabelas['5 Years'].rank(ascending = False)
# <ipython-input-27-62bd20c96505>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tabelas['Rank_10_anos'] = tabelas['10 Years'].rank(ascending = False)

# %%
tabelas['Rank_final'] = (tabelas['Rank_1_ano']+tabelas['Rank_3_anos']+tabelas['Rank_5_anos']
                         +tabelas['Rank_10_anos'])
## Queremos as 10 melhores que performaram bem em todas as variações de tempo consideradas.
melhores_etf = tabelas.sort_values(by = 'Rank_final')
#dropando as colunas que não nos servem mais, mostrando apenas o top10
melhores_etf.drop(columns=['Rank_final','Rank_1_ano','Rank_3_anos','Rank_5_anos', 'Rank_10_anos']).head(10)
# Out:
# <ipython-input-28-22e4505dc1a9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tabelas['Rank_final'] = (tabelas['Rank_1_ano']+tabelas['Rank_3_anos']+tabelas['Rank_5_anos']
#                                                      Name  \
# Ticker
# TAN                                     Invesco Solar ETF
# ICLN                      iShares Global Clean Energy ETF
# GRID    First Trust NASDAQ Clean Edge Smart Grid Infra...
# RWJ                  Invesco S&P SmallCap 600 Revenue ETF
# FXZ                   First Trust Materials AlphaDEX Fund
# RFV                 Invesco S&P MidCap 400 Pure Value ETF
# PSCC            Invesco S&P SmallCap Consumer Staples ETF
# XSD                            SPDR S&P Semiconductor ETF
# SPGP                             Invesco S&P 500 GARP ETF
# RGI          Invesco S&P 500 Equal Weight Industrials ETF
#
#                                 Segment                        Issuer  \
# Ticker
# TAN     Equity: Global Renewable Energy                       Invesco
# ICLN    Equity: Global Renewable Energy                     Blackrock
# GRID      Equity: Global Infrastructure                   First Trust
# RWJ            Equity: U.S. - Small Cap                       Invesco
# FXZ              Equity: U.S. Materials                   First Trust
# RFV        Equity: U.S. - Mid Cap Value                       Invesco
# PSCC      Equity: U.S. Consumer Staples                       Invesco
# XSD         Equity: U.S. Semiconductors  State Street Global Advisors
# SPGP    Equity: U.S. - Large Cap Growth                       Invesco
# RGI            Equity: U.S. Industrials                       Invesco
#
#        Expense Ratio       AUM  1 Year  3 Years  5 Years  10 Years
# Ticker
# TAN            0.69%    $2.49B  0.1432   0.2993   0.2809    0.1702
# ICLN           0.40%    $5.05B  0.0504   0.1656   0.1895    0.1287
# GRID           0.58%  $707.91M  0.0289   0.2013   0.1562    0.1321
# RWJ            0.39%    $1.19B  0.0220   0.2514   0.1410    0.1272
# FXZ            0.61%    $1.77B  0.1025   0.2376   0.1231    0.1105
# RFV            0.35%  $305.52M  0.0877   0.1933   0.1201    0.1158
# PSCC           0.29%   $56.65M  0.0809   0.1515   0.1062    0.1284
# XSD            0.35%    $1.33B -0.0389   0.2510   0.2602    0.2436
# SPGP           0.36%    $2.54B -0.0168   0.1351   0.1554    0.1545
# RGI            0.40%  $371.01M  0.0226   0.1235   0.1163    0.1302
