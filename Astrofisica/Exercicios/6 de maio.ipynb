# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
def funcao(param,x):
    return param[0] + param[1]*x

# %%
df = pd.read_csv('exemplo2_line.dat', delim_whitespace=True)
df
# Out:
#      +0.000  +31.467
# 0       1.0   -1.472
# 1       2.0   23.105
# 2       3.0   12.964
# 3       4.0   17.571
# 4       5.0   18.963
# 5       6.0    6.933
# 6       7.0   -0.635
# 7       8.0    2.828
# 8       9.0   22.885
# 9      10.0   10.527
# 10     11.0    5.373
# 11     12.0   20.141
# 12     13.0   27.074
# 13     14.0   19.170
# 14     15.0    1.750
# 15     16.0   25.480
# 16     17.0   39.114
# 17     18.0   29.181
# 18     19.0   18.088
# 19     20.0   21.826
# 20     21.0    3.319
# 21     22.0   -3.677
# 22     23.0   28.653
# 23     24.0   15.605
# 24     25.0   36.205
# 25     26.0   21.654
# 26     27.0   35.578
# 27     28.0    7.695
# 28     29.0   35.890
# 29     30.0   35.634
# ..      ...      ...
# 969   970.0  303.176
# 970   971.0  306.596
# 971   972.0  303.980
# 972   973.0  298.281
# 973   974.0  319.917
# 974   975.0  311.785
# 975   976.0  316.081
# 976   977.0  305.105
# 977   978.0  319.084
# 978   979.0  333.906
# 979   980.0  316.309
# ...

# %%
ele = pd.DataFrame(data = df.values, columns = ['x', 'y'])
ele
# Out:
#          x        y
# 0      1.0   -1.472
# 1      2.0   23.105
# 2      3.0   12.964
# 3      4.0   17.571
# 4      5.0   18.963
# 5      6.0    6.933
# 6      7.0   -0.635
# 7      8.0    2.828
# 8      9.0   22.885
# 9     10.0   10.527
# 10    11.0    5.373
# 11    12.0   20.141
# 12    13.0   27.074
# 13    14.0   19.170
# 14    15.0    1.750
# 15    16.0   25.480
# 16    17.0   39.114
# 17    18.0   29.181
# 18    19.0   18.088
# 19    20.0   21.826
# 20    21.0    3.319
# 21    22.0   -3.677
# 22    23.0   28.653
# 23    24.0   15.605
# 24    25.0   36.205
# 25    26.0   21.654
# 26    27.0   35.578
# 27    28.0    7.695
# 28    29.0   35.890
# 29    30.0   35.634
# ..     ...      ...
# 969  970.0  303.176
# 970  971.0  306.596
# 971  972.0  303.980
# 972  973.0  298.281
# 973  974.0  319.917
# 974  975.0  311.785
# 975  976.0  316.081
# 976  977.0  305.105
# 977  978.0  319.084
# 978  979.0  333.906
# 979  980.0  316.309
# 980  981.0  309.946
# 981  982.0  323.228
# ...

# %%
x = ele['x']
y = ele['y']

# %%
fun=funcao([4,0.5],x)
fun
# Out:
# 0        4.5
# 1        5.0
# 2        5.5
# 3        6.0
# 4        6.5
# 5        7.0
# 6        7.5
# 7        8.0
# 8        8.5
# 9        9.0
# 10       9.5
# 11      10.0
# 12      10.5
# 13      11.0
# 14      11.5
# 15      12.0
# 16      12.5
# 17      13.0
# 18      13.5
# 19      14.0
# 20      14.5
# 21      15.0
# 22      15.5
# 23      16.0
# 24      16.5
# 25      17.0
# 26      17.5
# 27      18.0
# 28      18.5
# 29      19.0
#        ...
# 969    489.0
# 970    489.5
# 971    490.0
# 972    490.5
# 973    491.0
# 974    491.5
# 975    492.0
# 976    492.5
# 977    493.0
# 978    493.5
# 979    494.0
# 980    494.5
# 981    495.0
# 982    495.5
# 983    496.0
# 984    496.5
# 985    497.0
# 986    497.5
# 987    498.0
# 988    498.5
# 989    499.0
# 990    499.5
# 991    500.0
# 992    500.5
# 993    501.0
# 994    501.5
# 995    502.0
# 996    502.5
# 997    503.0
# 998    503.5
# Name: x, Length: 999, dtype: float64

# %%
plt.plot(x, y,'.')
plt.plot(x,fun,label='Ajuste', color='red')
#plt.axvline(24000, color='r', linestyle='dotted', linewidth=2)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
fun_f=funcao([4,0.315],x)
plt.plot(x, y,'.')
plt.plot(x,fun_f,label='Ajuste', color='red')
#plt.axvline(24000, color='r', linestyle='dotted', linewidth=2)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
def min_quad(y,fun_f):
    S = np.zeros((len(fun_f)))
    for i in range(len(fun_f)):
        S[i] = (y[i] - fun_f[i])**2
    return S.sum()

# %%
min_quad(y,fun_f)
# Out:
# 175953.236639

# %%
min_quad(y,fun)
# Out:
# 11334479.625739003

# %% [markdown]
#  - Menor minimo quadrado possível é preferível.

# %%
do = len(x) - 2

# %%
min_quad(y,fun_f)/do
# Out:
# 176.48268469307925
